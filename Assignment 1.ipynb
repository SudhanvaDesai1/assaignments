# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# * -is a expression
# 'hello' – is a value
# -87.8 – is a value
# - -is a expression
# /  -is a expression
# +	-is a expression
# 6 –is a value
#
# 2. What is the difference between string and variable?
# Ans: String is a data type whereas, a variable is a place where the datatypes are stored.
#
# 3. Describe three different data types.
# Int –This datatype is used to store the values in the integer format.
# Eg. 5,7,2,etc.
# Float  –This datatype is used to store the values in the decimal format including a decimal point.
# Eg. 5.22, 3.12,etc.
# Str –This datatype is used to store the sequence of the alphanumeric characters enclosed within  the single quotes(‘’) or double quotes(“”)
# Eg. “Sudhanva”, ‘@animals’,’1234’.
#
# 4. What is an expression made up of? What do all expressions do?
# Ans: The Expression is made up of the mathematical operators which perform some specific mathematical operations or perform a specific task.
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans: The Expression is something that evalues to a  value. While  the Statement is used to do something with the given line.
#
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans: bacon contains 22 as there is no assigning of the bacon+1 value to  something
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans: ‘spamspamspam’
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans: According to the rules of naming the variable the variable name should always start with the Alphabet or has to start with a under score(  _  ), Hence the 100 as a variable name is a invalid one.
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans: str() –To get a string version of value
#          Int() –To get a integer verion of value
#          Float() –To get a floating version of value
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans: The python compiler can’t concatenate the string with the integer type of data. So, in order to solve the issue we have to either put quote the numbers or use string function as
# Sol 1.  'I have eaten ' +’ 99 ‘+ ' burritos.'
# Sol 2. 'I have eaten ' + str(99) + ' burritos.'
